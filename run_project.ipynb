# %%
# Check if the GPU is correctly allocated and view its specifications
# !nvidia-smi

# %%
import os

# Define the repository URL and project folder name
repo_url = "https://github.com/hung51607602/COMP3065_Group-Project.git"
project_name = "COMP3065_Group-Project"

# Clone the repository if it doesn't exist, otherwise pull the latest changes
if not os.path.exists(project_name):
    print(f"Cloning repository from {repo_url}...")
    # !git clone {repo_url}
else:
    print(f"Directory '{project_name}' already exists. Pulling latest updates...")
    # Change directory temporarily to pull latest changes
    # %cd {project_name}
    # !git pull
    # %cd ..

# Change the working directory to the project folder
# Note: We use %cd instead of !cd to ensure the directory change persists in the notebook
# %cd {project_name}

# Verify the current directory and list files to ensure successful setup
print("\nCurrent Working Directory:")
# !pwd
print("\nFiles in the project directory:")
# !ls -la

# %%
import os

# Automatically install dependencies if requirements.txt exists
if os.path.exists("requirements.txt"):
    print("Found requirements.txt! Installing dependencies...")
    # !pip install -r requirements.txt
else:
    print("No requirements.txt found.")
    print("If your project needs specific packages, you can install them manually.")
    # Example: uncomment the line below to install specific packages
    # !pip install torch torchvision torchaudio pandas numpy

# %%
# Run your main Python script to start training or inference
# Note: Replace 'main.py' with the actual entry point of your project!
# You can also append any required command-line arguments here.

# !python main.py
