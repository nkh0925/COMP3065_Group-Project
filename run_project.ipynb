# %%
# Check if the GPU is correctly allocated and view its specifications
# !nvidia-smi
# Out:
# Thu Mar 19 05:08:38 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
from google.colab import drive

# Mount Google Drive to access files directly
# You will be prompted to grant Colab access to your Drive
drive.mount('/content/drive')

# Define the path to your project folder in Google Drive
# UPDATE THIS PATH if you named your folder differently!
PROJECT_DIR = '/content/drive/MyDrive/COMP3065_Group-Project'

# Create the directory if it doesn't exist (just in case)
os.makedirs(PROJECT_DIR, exist_ok=True)

# Change the current working directory to your project folder
os.chdir(PROJECT_DIR)

print(f"Workspace successfully set to: {os.getcwd()}")
# Out:
# Cloning repository from https://github.com/hung51607602/COMP3065_Group-Project.git...
# Cloning into 'COMP3065_Group-Project'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 55 (delta 1), reused 2 (delta 0), pack-reused 48 (from 1)
# Receiving objects: 100% (55/55), 41.07 MiB | 20.77 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/COMP3065_Group-Project
#
# Current Working Directory:
# /content/COMP3065_Group-Project
#
# Files in the project directory:
# total 88
# drwxr-xr-x 6 root root  4096 Mar 19 05:08 .
# drwxr-xr-x 1 root root  4096 Mar 19 05:08 ..
# drwxr-xr-x 2 root root  4096 Mar 19 05:08 configs
# drwxr-xr-x 4 root root  4096 Mar 19 05:08 data
# -rw-r--r-- 1 root root  3373 Mar 19 05:08 download_dataset.py
# -rw-r--r-- 1 root root  6148 Mar 19 05:08 .DS_Store
# -rw-r--r-- 1 root root    76 Mar 19 05:08 .env
# drwxr-xr-x 8 root root  4096 Mar 19 05:08 .git
# -rw-r--r-- 1 root root  3544 Mar 19 05:08 main.py
# -rw-r--r-- 1 root root 35217 Mar 19 05:08 README.md
# -rw-r--r-- 1 root root   570 Mar 19 05:08 requirements.txt
# -rw-r--r-- 1 root root  2749 Mar 19 05:08 run_project.ipynb
# drwxr-xr-x 3 root root  4096 Mar 19 05:08 src
# -rw-r--r-- 1 root root     0 Mar 19 05:08 training.log

# %%
import os

# Automatically install dependencies if requirements.txt exists
if os.path.exists("requirements.txt"):
    print("Found requirements.txt! Installing dependencies...")
    # !pip install -r requirements.txt
else:
    print("No requirements.txt found.")
    print("If your project needs specific packages, you can install them manually.")
    # Example: uncomment the line below to install specific packages
    # !pip install torch torchvision torchaudio pandas numpy
# Out:
# Found requirements.txt! Installing dependencies...
# Requirement already satisfied: kaggle>=1.6.14 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (2.0.0)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (2.2.2)
# Requirement already satisfied: numpy>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 10)) (2.0.2)
# Requirement already satisfied: python-dotenv>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (1.2.2)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (4.67.3)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 19)) (6.0.3)
# Requirement already satisfied: scikit-learn>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 22)) (1.6.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (2.10.0+cu128)
# Requirement already satisfied: bleach in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (0.1.16)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (26.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (5.29.6)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (8.0.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (2.32.4)
# Requirement already satisfied: urllib3>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from kaggle>=1.6.14->-r requirements.txt (line 6)) (2.5.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 9)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0.0->-r requirements.txt (line 9)) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 22)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 22)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r requirements.txt (line 25)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->-r requirements.txt (line 25)) (1.4.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil->kaggle>=1.6.14->-r requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r requirements.txt (line 25)) (1.3.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach->kaggle>=1.6.14->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r requirements.txt (line 25)) (3.0.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.12/dist-packages (from python-slugify->kaggle>=1.6.14->-r requirements.txt (line 6)) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle>=1.6.14->-r requirements.txt (line 6)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle>=1.6.14->-r requirements.txt (line 6)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kaggle>=1.6.14->-r requirements.txt (line 6)) (2026.2.25)

# %%
# Run your main Python script to start training or inference
# Note: Replace 'main.py' with the actual entry point of your project!
# You can also append any required command-line arguments here.

# !python main.py
# Out:
# 2026-03-19 05:08:53,988 - INFO - NumExpr defaulting to 2 threads.
# 2026-03-19 05:08:55,603 - INFO - ======================================================================
# 2026-03-19 05:08:55,604 - INFO -   ISOT Fake News Detection — Training Pipeline
# 2026-03-19 05:08:55,604 - INFO - ======================================================================
# 2026-03-19 05:08:55,611 - INFO - Configuration loaded successfully from 'configs/config.yaml'
# 2026-03-19 05:08:55,759 - INFO - Random seed set to 42
# 2026-03-19 05:08:55,760 - INFO - Using device: cuda
# 2026-03-19 05:08:55,760 - INFO - Building data pipeline …
# 2026-03-19 05:08:55,760 - INFO - Random seed set to 42
# 2026-03-19 05:08:55,760 - INFO - ============================================================
# 2026-03-19 05:08:55,760 - INFO - Step 1 / 5 — Loading and merging raw data …
# 2026-03-19 05:08:55,761 - INFO - ============================================================
# 2026-03-19 05:08:57,523 - WARNING - Dropped 631 rows with empty/NaN text.
# 2026-03-19 05:08:57,523 - INFO - Loaded 44267 samples (Real: 21416 | Fake: 22851)
# 2026-03-19 05:08:57,524 - INFO - ============================================================
# 2026-03-19 05:08:57,524 - INFO - Step 2 / 5 — Stratified dataset splitting …
# 2026-03-19 05:08:57,524 - INFO - ============================================================
# 2026-03-19 05:08:57,576 - INFO - Split sizes — Train: 30986 (70.0%) | Val: 6640 (15.0%) | Test: 6641 (15.0%)
# 2026-03-19 05:08:57,581 - INFO - ============================================================
# 2026-03-19 05:08:57,581 - INFO - Step 3 / 5 — Building vocabulary (train-only) …
# 2026-03-19 05:08:57,581 - INFO - ============================================================
# 2026-03-19 05:09:12,940 - INFO - Vocabulary built: 89000 unique words (min_freq=2). Total vocab size (incl. special tokens): 89002
# 2026-03-19 05:09:13,031 - INFO - Saved word2idx (89002 entries) to 'data/processed/word2idx.json'
# 2026-03-19 05:09:13,032 - INFO - ============================================================
# 2026-03-19 05:09:13,032 - INFO - Step 4 / 5 — Encoding sequences …
# 2026-03-19 05:09:13,032 - INFO - ============================================================
# 2026-03-19 05:09:35,458 - INFO - ============================================================
# 2026-03-19 05:09:35,459 - INFO - Step 5 / 5 — Creating DataLoaders …
# 2026-03-19 05:09:35,459 - INFO - ============================================================
# 2026-03-19 05:09:35,476 - INFO - DataLoaders ready — Train batches: 485 | Val batches: 104 | Test batches: 104 | Vocab size: 89002
# 2026-03-19 05:09:35,484 - INFO - Data pipeline ready. Vocab size: 89002
# 2026-03-19 05:09:35,484 - INFO - Building LSTM model …
# 2026-03-19 05:09:35,484 - WARNING - GloVe file not found at 'data/glove/glove.6B.100d.txt'. Falling back to random initialisation.
# 2026-03-19 05:09:35,594 - INFO - FakeNewsLSTM initialised — vocab: 89002 | embed: 100 | hidden: 128 | layers: 2 | bidir: True | classes: 2 | dropout(embed=0.30, lstm=0.30, fc=0.50)
# 2026-03-19 05:09:35,594 - INFO - Model parameters — Total: 9,531,498 | Trainable: 9,531,498
# 2026-03-19 05:09:35,595 - INFO - Starting training …
# 2026-03-19 05:09:41,195 - INFO - Optimizer: adam | LR: 0.001 | Weight decay: 1e-05
# 2026-03-19 05:09:41,195 - INFO - ======================================================================
# 2026-03-19 05:09:41,195 - INFO - Starting training for 20 epochs on cuda
# 2026-03-19 05:09:41,195 - INFO - ======================================================================
# 2026-03-19 05:10:06,278 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:10:06,278 - INFO - Epoch 1/20 (25.1s) | LR: 1.00e-03 | Train Loss: 0.2456 | Val Loss: 0.1184
# 2026-03-19 05:10:06,278 - INFO -   Train Metrics — Acc: 0.9002 | Fake[P: 0.9026  R: 0.9042  F1: 0.9034] | Real[P: 0.8976  R: 0.8959  F1: 0.8967]
# 2026-03-19 05:10:06,279 - INFO -   Val   Metrics — Acc: 0.9617 | Fake[P: 0.9774  R: 0.9478  F1: 0.9624] | Real[P: 0.9460  R: 0.9767  F1: 0.9611]
# 2026-03-19 05:10:06,483 - INFO -   ★ New best model saved (epoch 1) — Recall_Fake: 0.9478 | F1_Fake: 0.9624 | Acc: 0.9617
# 2026-03-19 05:10:30,355 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:10:30,355 - INFO - Epoch 2/20 (23.9s) | LR: 1.00e-03 | Train Loss: 0.1137 | Val Loss: 0.0558
# 2026-03-19 05:10:30,355 - INFO -   Train Metrics — Acc: 0.9602 | Fake[P: 0.9642  R: 0.9585  F1: 0.9613] | Real[P: 0.9560  R: 0.9620  F1: 0.9590]
# 2026-03-19 05:10:30,355 - INFO -   Val   Metrics — Acc: 0.9822 | Fake[P: 0.9851  R: 0.9805  F1: 0.9827] | Real[P: 0.9792  R: 0.9841  F1: 0.9817]
# 2026-03-19 05:10:30,630 - INFO -   ★ New best model saved (epoch 2) — Recall_Fake: 0.9805 | F1_Fake: 0.9827 | Acc: 0.9822
# 2026-03-19 05:10:54,233 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:10:54,233 - INFO - Epoch 3/20 (23.6s) | LR: 1.00e-03 | Train Loss: 0.0757 | Val Loss: 0.0492
# 2026-03-19 05:10:54,233 - INFO -   Train Metrics — Acc: 0.9740 | Fake[P: 0.9748  R: 0.9749  F1: 0.9748] | Real[P: 0.9732  R: 0.9731  F1: 0.9731]
# 2026-03-19 05:10:54,233 - INFO -   Val   Metrics — Acc: 0.9825 | Fake[P: 0.9851  R: 0.9810  F1: 0.9830] | Real[P: 0.9799  R: 0.9841  F1: 0.9820]
# 2026-03-19 05:10:54,519 - INFO -   ★ New best model saved (epoch 3) — Recall_Fake: 0.9810 | F1_Fake: 0.9830 | Acc: 0.9825
# 2026-03-19 05:11:18,242 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:11:18,242 - INFO - Epoch 4/20 (23.7s) | LR: 1.00e-03 | Train Loss: 0.0594 | Val Loss: 0.0352
# 2026-03-19 05:11:18,242 - INFO -   Train Metrics — Acc: 0.9796 | Fake[P: 0.9796  R: 0.9809  F1: 0.9803] | Real[P: 0.9796  R: 0.9782  F1: 0.9789]
# 2026-03-19 05:11:18,242 - INFO -   Val   Metrics — Acc: 0.9877 | Fake[P: 0.9912  R: 0.9848  F1: 0.9880] | Real[P: 0.9839  R: 0.9907  F1: 0.9873]
# 2026-03-19 05:11:18,495 - INFO -   ★ New best model saved (epoch 4) — Recall_Fake: 0.9848 | F1_Fake: 0.9880 | Acc: 0.9877
# 2026-03-19 05:11:42,118 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:11:42,118 - INFO - Epoch 5/20 (23.6s) | LR: 1.00e-03 | Train Loss: 0.0490 | Val Loss: 0.0380
# 2026-03-19 05:11:42,118 - INFO -   Train Metrics — Acc: 0.9851 | Fake[P: 0.9857  R: 0.9853  F1: 0.9855] | Real[P: 0.9843  R: 0.9848  F1: 0.9846]
# 2026-03-19 05:11:42,118 - INFO -   Val   Metrics — Acc: 0.9880 | Fake[P: 0.9900  R: 0.9866  F1: 0.9883] | Real[P: 0.9857  R: 0.9894  F1: 0.9876]
# 2026-03-19 05:11:42,403 - INFO -   ★ New best model saved (epoch 5) — Recall_Fake: 0.9866 | F1_Fake: 0.9883 | Acc: 0.9880
# 2026-03-19 05:12:06,081 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:12:06,082 - INFO - Epoch 6/20 (23.7s) | LR: 1.00e-03 | Train Loss: 0.0346 | Val Loss: 0.0334
# 2026-03-19 05:12:06,082 - INFO -   Train Metrics — Acc: 0.9895 | Fake[P: 0.9904  R: 0.9892  F1: 0.9898] | Real[P: 0.9885  R: 0.9898  F1: 0.9891]
# 2026-03-19 05:12:06,082 - INFO -   Val   Metrics — Acc: 0.9902 | Fake[P: 0.9850  R: 0.9962  F1: 0.9906] | Real[P: 0.9959  R: 0.9838  F1: 0.9898]
# 2026-03-19 05:12:06,330 - INFO -   ★ New best model saved (epoch 6) — Recall_Fake: 0.9962 | F1_Fake: 0.9906 | Acc: 0.9902
# 2026-03-19 05:12:30,155 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:12:30,156 - INFO - Epoch 7/20 (23.8s) | LR: 1.00e-03 | Train Loss: 0.0338 | Val Loss: 0.0365
# 2026-03-19 05:12:30,156 - INFO -   Train Metrics — Acc: 0.9894 | Fake[P: 0.9907  R: 0.9886  F1: 0.9897] | Real[P: 0.9879  R: 0.9901  F1: 0.9890]
# 2026-03-19 05:12:30,156 - INFO -   Val   Metrics — Acc: 0.9877 | Fake[P: 0.9935  R: 0.9825  F1: 0.9880] | Real[P: 0.9815  R: 0.9932  F1: 0.9873]
# 2026-03-19 05:12:30,156 - INFO - EarlyStopping: no improvement for 1 / 5 epochs
# 2026-03-19 05:12:53,304 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:12:53,304 - INFO - Epoch 8/20 (23.1s) | LR: 1.00e-03 | Train Loss: 0.0268 | Val Loss: 0.0256
# 2026-03-19 05:12:53,304 - INFO -   Train Metrics — Acc: 0.9911 | Fake[P: 0.9924  R: 0.9904  F1: 0.9914] | Real[P: 0.9897  R: 0.9919  F1: 0.9908]
# 2026-03-19 05:12:53,304 - INFO -   Val   Metrics — Acc: 0.9917 | Fake[P: 0.9915  R: 0.9924  F1: 0.9920] | Real[P: 0.9919  R: 0.9910  F1: 0.9914]
# 2026-03-19 05:12:53,304 - INFO - EarlyStopping: no improvement for 2 / 5 epochs
# 2026-03-19 05:13:16,109 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:13:16,109 - INFO - Epoch 9/20 (22.8s) | LR: 1.00e-03 | Train Loss: 0.0210 | Val Loss: 0.0251
# 2026-03-19 05:13:16,109 - INFO -   Train Metrics — Acc: 0.9930 | Fake[P: 0.9942  R: 0.9922  F1: 0.9932] | Real[P: 0.9917  R: 0.9939  F1: 0.9928]
# 2026-03-19 05:13:16,110 - INFO -   Val   Metrics — Acc: 0.9920 | Fake[P: 0.9879  R: 0.9968  F1: 0.9923] | Real[P: 0.9965  R: 0.9869  F1: 0.9917]
# 2026-03-19 05:13:16,466 - INFO -   ★ New best model saved (epoch 9) — Recall_Fake: 0.9968 | F1_Fake: 0.9923 | Acc: 0.9920
# 2026-03-19 05:13:39,904 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:13:39,904 - INFO - Epoch 10/20 (23.4s) | LR: 1.00e-03 | Train Loss: 0.0160 | Val Loss: 0.0288
# 2026-03-19 05:13:39,904 - INFO -   Train Metrics — Acc: 0.9945 | Fake[P: 0.9946  R: 0.9949  F1: 0.9947] | Real[P: 0.9945  R: 0.9942  F1: 0.9944]
# 2026-03-19 05:13:39,904 - INFO -   Val   Metrics — Acc: 0.9916 | Fake[P: 0.9862  R: 0.9977  F1: 0.9919] | Real[P: 0.9975  R: 0.9851  F1: 0.9912]
# 2026-03-19 05:13:40,143 - INFO -   ★ New best model saved (epoch 10) — Recall_Fake: 0.9977 | F1_Fake: 0.9919 | Acc: 0.9916
# 2026-03-19 05:14:03,612 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:14:03,612 - INFO - Epoch 11/20 (23.5s) | LR: 1.00e-03 | Train Loss: 0.0160 | Val Loss: 0.0186
# 2026-03-19 05:14:03,612 - INFO -   Train Metrics — Acc: 0.9947 | Fake[P: 0.9946  R: 0.9951  F1: 0.9948] | Real[P: 0.9947  R: 0.9943  F1: 0.9945]
# 2026-03-19 05:14:03,612 - INFO -   Val   Metrics — Acc: 0.9944 | Fake[P: 0.9916  R: 0.9977  F1: 0.9946] | Real[P: 0.9975  R: 0.9910  F1: 0.9942]
# 2026-03-19 05:14:03,877 - INFO -   ★ New best model saved (epoch 11) — Recall_Fake: 0.9977 | F1_Fake: 0.9946 | Acc: 0.9944
# 2026-03-19 05:14:03,877 - INFO - EarlyStopping: no improvement for 1 / 5 epochs
# 2026-03-19 05:14:27,379 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:14:27,379 - INFO - Epoch 12/20 (23.5s) | LR: 1.00e-03 | Train Loss: 0.0099 | Val Loss: 0.0229
# 2026-03-19 05:14:27,379 - INFO -   Train Metrics — Acc: 0.9968 | Fake[P: 0.9968  R: 0.9971  F1: 0.9969] | Real[P: 0.9969  R: 0.9965  F1: 0.9967]
# 2026-03-19 05:14:27,379 - INFO -   Val   Metrics — Acc: 0.9935 | Fake[P: 0.9916  R: 0.9959  F1: 0.9937] | Real[P: 0.9956  R: 0.9910  F1: 0.9933]
# 2026-03-19 05:14:27,379 - INFO - EarlyStopping: no improvement for 2 / 5 epochs
# 2026-03-19 05:14:50,678 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:14:50,678 - INFO - Epoch 13/20 (23.3s) | LR: 1.00e-03 | Train Loss: 0.0076 | Val Loss: 0.0245
# 2026-03-19 05:14:50,678 - INFO -   Train Metrics — Acc: 0.9975 | Fake[P: 0.9978  R: 0.9973  F1: 0.9976] | Real[P: 0.9971  R: 0.9977  F1: 0.9974]
# 2026-03-19 05:14:50,678 - INFO -   Val   Metrics — Acc: 0.9917 | Fake[P: 0.9915  R: 0.9924  F1: 0.9920] | Real[P: 0.9919  R: 0.9910  F1: 0.9914]
# 2026-03-19 05:14:50,678 - INFO - EarlyStopping: no improvement for 3 / 5 epochs
# 2026-03-19 05:15:14,183 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:15:14,183 - INFO - Epoch 14/20 (23.5s) | LR: 1.00e-03 | Train Loss: 0.0096 | Val Loss: 0.0214
# 2026-03-19 05:15:14,183 - INFO -   Train Metrics — Acc: 0.9965 | Fake[P: 0.9968  R: 0.9965  F1: 0.9967] | Real[P: 0.9963  R: 0.9966  F1: 0.9964]
# 2026-03-19 05:15:14,184 - INFO -   Val   Metrics — Acc: 0.9931 | Fake[P: 0.9965  R: 0.9901  F1: 0.9933] | Real[P: 0.9895  R: 0.9963  F1: 0.9929]
# 2026-03-19 05:15:14,184 - INFO - EarlyStopping: no improvement for 4 / 5 epochs
# 2026-03-19 05:15:37,750 - INFO - ----------------------------------------------------------------------
# 2026-03-19 05:15:37,750 - INFO - Epoch 15/20 (23.6s) | LR: 1.00e-03 | Train Loss: 0.0089 | Val Loss: 0.0244
# 2026-03-19 05:15:37,750 - INFO -   Train Metrics — Acc: 0.9968 | Fake[P: 0.9970  R: 0.9969  F1: 0.9969] | Real[P: 0.9967  R: 0.9968  F1: 0.9967]
# 2026-03-19 05:15:37,750 - INFO -   Val   Metrics — Acc: 0.9941 | Fake[P: 0.9930  R: 0.9956  F1: 0.9943] | Real[P: 0.9953  R: 0.9925  F1: 0.9939]
# 2026-03-19 05:15:37,751 - INFO - EarlyStopping: no improvement for 5 / 5 epochs
# 2026-03-19 05:15:37,751 - INFO - Early stopping triggered at epoch 15. Best epoch: 11
# 2026-03-19 05:15:37,751 - INFO - Restored best model weights from epoch 11
# 2026-03-19 05:15:37,752 - INFO - ======================================================================
# 2026-03-19 05:15:37,752 - INFO - Training complete.
# 2026-03-19 05:15:37,752 - INFO - Best epoch: 11 | Recall_Fake: 0.9977 | F1_Fake: 0.9946 | Acc: 0.9944
# 2026-03-19 05:15:37,752 - INFO - ======================================================================
# 2026-03-19 05:15:39,345 - INFO - Validation Classification Report (best model):
#               precision    recall  f1-score   support
#
#         Real     0.9975    0.9910    0.9942      3212
#         Fake     0.9916    0.9977    0.9946      3428
#
#     accuracy                         0.9944      6640
#    macro avg     0.9945    0.9943    0.9944      6640
# weighted avg     0.9944    0.9944    0.9944      6640
#
# 2026-03-19 05:15:39,345 - INFO - Confusion Matrix (rows=actual, cols=predicted):
# [[3183   29]
#  [   8 3420]]
# 2026-03-19 05:15:39,346 - INFO - Training history saved to 'checkpoints/training_history.json'
# 2026-03-19 05:15:39,347 - INFO - ======================================================================
# 2026-03-19 05:15:39,347 - INFO -   TRAINING COMPLETE
# 2026-03-19 05:15:39,347 - INFO -   Best epoch : 11
# 2026-03-19 05:15:39,347 - INFO -   Recall_Fake: 0.9977  (★ primary metric)
# 2026-03-19 05:15:39,347 - INFO -   F1_Fake    : 0.9946
# 2026-03-19 05:15:39,347 - INFO -   Precision_F: 0.9916
# 2026-03-19 05:15:39,347 - INFO -   Accuracy   : 0.9944
# 2026-03-19 05:15:39,347 - INFO -   Val Loss   : 0.0186
# 2026-03-19 05:15:39,347 - INFO - ======================================================================
# 2026-03-19 05:15:39,347 - INFO - Model checkpoint: checkpoints/best_model.pt
# 2026-03-19 05:15:39,347 - INFO - Training history: checkpoints/training_history.json
# 2026-03-19 05:15:39,348 - INFO - Training log    : training.log
